# %%
# %%bash
# cd /kaggle/working
# rm -rf *
# git clone https://github.com/kshashankrao/MonoDETR.git
# cd /kaggle/working/MonoDETR && git pull
#
#
# # Compile the operators
# cd lib/models/monodetr/ops/
# bash make.sh
# cd ../../../..
# # Link Dataset and download splits
# mkdir -p data/KITTIDataset/ImageSets
# ln -s /kaggle/input/datasets/garymk/kitti-3d-object-detection-dataset/training data/KITTIDataset/training
# ln -s /kaggle/input/datasets/garymk/kitti-3d-object-detection-dataset/testing data/KITTIDataset/testing
# cd data/KITTIDataset/ImageSets
# wget -q https://raw.githubusercontent.com/traveller59/second.pytorch/master/second/data/ImageSets/train.txt
# wget -q https://raw.githubusercontent.com/traveller59/second.pytorch/master/second/data/ImageSets/val.txt
# wget -q https://raw.githubusercontent.com/traveller59/second.pytorch/master/second/data/ImageSets/test.txt
# wget -q https://raw.githubusercontent.com/traveller59/second.pytorch/master/second/data/ImageSets/trainval.txt
# Out:
# Already up to date.
# running build
# running build_py
# creating build/lib.linux-x86_64-cpython-312/modules
# copying modules/ms_deform_attn.py -> build/lib.linux-x86_64-cpython-312/modules
# copying modules/__init__.py -> build/lib.linux-x86_64-cpython-312/modules
# creating build/lib.linux-x86_64-cpython-312/functions
# copying functions/ms_deform_attn_func.py -> build/lib.linux-x86_64-cpython-312/functions
# copying functions/__init__.py -> build/lib.linux-x86_64-cpython-312/functions
# running build_ext
# building 'MultiScaleDeformableAttention' extension
# creating /kaggle/working/MonoDETR/lib/models/monodetr/ops/build/temp.linux-x86_64-cpython-312/kaggle/working/MonoDETR/lib/models/monodetr/ops/src/cpu
# creating /kaggle/working/MonoDETR/lib/models/monodetr/ops/build/temp.linux-x86_64-cpython-312/kaggle/working/MonoDETR/lib/models/monodetr/ops/src/cuda
# ...

# %%
# !cd /kaggle/working/MonoDETR && git pull 
# %cd /kaggle/working/MonoDETR
# !bash train.sh configs/monodetr.yaml
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 375 bytes | 375.00 KiB/s, done.
# From https://github.com/kshashankrao/MonoDETR
#    e3a935d..132b21e  main       -> origin/main
# Updating e3a935d..132b21e
# Fast-forward
#  configs/monodetr.yaml | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# /kaggle/working/MonoDETR
# 2026-08-23 20:55:38,199   INFO  ###################  Training  ##################
# 2026-08-23 20:55:38,199   INFO  Batch Size: 8
# 2026-08-23 20:55:38,199   INFO  Learning Rate: 0.000200
# epochs:   0%|                                           | 0/195 [00:00<?, ?it/s]>>>>>>> Epoch: 0:
#
# iters:   0%|                                            | 0/464 [00:00<?, ?it/s]---- 0 ----
# loss_detr: 130.15,
# ...

# %%
# !nvidia-smi
# Out:
# Sun Aug 23 20:54:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             14W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
